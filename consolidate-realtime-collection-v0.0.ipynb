# %%
import ast
data = ast.literal_eval(body)
stations = pd.DataFrame(data['data']['stations'])

# %%
stations
# Out:
#     eightd_active_station_services  eightd_has_available_keys  is_installed  \
# 0                              NaN                      False             1
# 1                              NaN                      False             1
# 2                              NaN                      False             1
# 3                              NaN                      False             1
# 4                              NaN                      False             1
# 5                              NaN                      False             1
# 6                              NaN                      False             1
# 7                              NaN                      False             1
# 8                              NaN                      False             1
# 9                              NaN                      False             1
# 10                             NaN                      False             1
# ...

# %%
file = open('/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523065429.json','r')
body = file.read()
data = ast.literal_eval(body)
stations = pd.DataFrame(data['data']['stations'])

# %%
import glob
path ="/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/*/*.json"
all_json = glob.glob(path)

# %%
all_json
# Out:
# ['/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523063448.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523064704.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523064777.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523064831.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523064894.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523064957.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523065020.json',
#  '/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_logs/2018-04-06/station_status_1523065072.json',
# ...

# %%
import pandas as pd

# %%
bikeDF = pd.DataFrame()
list_ = []
for json in all_json:
    df = pd.read_csv(csv,index_col=None, header=0)
    list_.append(df)
bikeDF = pd.concat(list_)

# %%
stationDF = pd.DataFrame()
_list = []
for json in all_json:
    file = open(json,'r')
    body = file.read()
    data = ast.literal_eval(body)
    stations = pd.DataFrame(data['data']['stations'])
    _list.append(stations)
    file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e7deb8f4b799> in <module>()
#       8     _list.append(stations)
#       9     file.close()
# ---> 10 stationDF = pd.concat(list_)
#
# NameError: name 'list_' is not defined

# %%
stationDF = pd.concat(_list)

# %%
stationDF[['last_reported','num_bikes_available', 'station_id']].sort(['station_id'])
# Out:
#      last_reported  num_bikes_available station_id
# 0       1523061840                   15         72
# 1       1523062264                   18         79
# 2       1523060972                   21         82
# 3       1523062354                   17         83
# 4       1523060329                    9        119
# 5       1523062039                   15        120
# 6       1523062952                   31        127
# 7       1523063311                    7        128
# 8       1523062029                   13        143
# 9       1523062908                   12        144
# 10      1523062309                   26        146
# 11      1523063217                   30        150
# 12      1523063336                    3        151
# 13      1523062678                    0        152
# 14      1523061211                   22        157
# 15      1523062338                   28        161
# 16      1523063307                    0        164
# ...

# %%
outputPath = "/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/event_csv/2018-04-06.csv"
stationDF.to_csv(outputPath, sep=",",index=False)

# %%
outputPath = "/Users/chuamelia/Google Drive/Forecasting Time Series/citi-bike/station_prep_min.csv"
minDF = stationDF[stationDF['station_id'].isin(_numlist)]
minDF = minDF[['last_reported','num_bikes_available', 'station_id']]
minDF.to_csv(outputPath, sep=",",index=False)

# %%
_numlist = []
for num in range(264,276):
    _numlist.append(str(num))

# %%
import numpy as np

# %%
agg = stationDF.groupby('station_id').agg({'num_bikes_available': np.max}).reset_index()
_numlist = agg[agg['num_bikes_available'] > 30]['station_id'].tolist()

# %%
_numlist
# Out:
# ['72',
#  '73',
#  '74',
#  '75',
#  '76',
#  '77',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '90',
#  '91',
#  '92',
#  '93',
#  '94',
#  '95',
#  '96',
#  '97',
#  '98',
#  '99',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '170',
#  '171',
#  '172',
#  '173',
# ...
